# %%
help([])
# Out:
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
# ...

# %%
class SinglyLinkedList:
    self = sll
    
    class __Node:
        def __init__(self,data):
            self.data = data
            self.next = None

        def __init__(self):
            self.head = None

        def append(self,value):
            new_node = self.__Node(value)
            if not self.head:
                self.head = new_node
            else:
                current = self.head
                while current.next:
                    current = current.next
                current.next = new_node

        def insert(self, index, value):
            # Implement insert considering the following:
            #1. You can insert a new element/value anywhere in the list
            #2. The new node must go before the target index, not after
            #Note: You can replace the head with this method
            new_node = self.__Node(value)
            if not self.head:
                current = self.head
                counter = 0
                prev = None
                while index != counter and current.next:
                    prev = current
                    current = current.next
                    counter += 1
                if index == 0:
                    # replace the head
                        new_node.next= new_node
                        self.head = new_node

                elif current.next:
                    if index == counter:
                        # replace the head
                        prev.next = new_node
                        new_node.next= current
                else:
                    current.next = new_node
                    

        def remove(self, value):
            pass

        def index(self, value):
            pass

        def __len__(self):
            pass

        def __str__(self):
            out ="["
            current = self.head
            if self.head:
                out += "%s" % current.data
                current = current.next
                while current:
                    out += ", %s" % current.data
                    current = current.next
            out += "]"    
            return out

# %%
mylist= [1,2,3,4]

mylist.append(5)

mylist
# Out:
# [1, 2, 3, 4, 5]

# %%
mylist =[] #not my list; This is apython list.
sll = SinglyLinkedList()

# if the list is empty:
print(mylist)
print( sll)

# if the list contains only one element:
mylist.append(1)
sll.append(1)
print(mylist)
print(sll)
# if the list contains more than one element:
mylist.append(2)
sll.append(2)
print(mylist)
print( sll)

#MORE data 
for number in reange(3,6):
    mylist.append(number)
    sll.append(number)
# Out:
# []
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 10
#       8 # if the list contains only one element:
#       9 mylist.append(1)
# ---> 10 sll.append(1)
#      11 print(mylist)
#      12 print(sll)
#
# AttributeError: 'SinglyLinkedList' object has no attribute 'append'

# %%
mylist= []

mylist.insert(0,1)

print(mylist)

mylist.insert(1000,2)

print(mylist)
# Out:
# [1]
# [1, 2]
